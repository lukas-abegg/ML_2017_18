# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Task a) Preprocessing and Exploration of the Dataset

# %%
with open("boston") as f:
    datastr = f.readlines()[22:]

# %%
import re
data = []
for i,v in enumerate(datastr):
    if i%2==0:
        temp = datastr[i] + datastr[i+1]
        temp = temp.replace("\n", "")[1:]
        temp = temp.replace("\\s+",";")
        data.append(re.sub(" +", ";", temp)+"\n")

# %%
from io import StringIO
testdata = StringIO("".join(map(str,data)))

# %%
columns = []
with open("boston") as f:
    coltxt = f.readlines()[7:21]
for i,v in enumerate(coltxt):
    temp = v[1:10]
    columns.append(re.sub(" +","",temp))

# %%
boston = pd.read_csv(testdata, names=columns, sep=";")
boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222
# 5    0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222
# 6    0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311
# 7    0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311
# 8    0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311
# 9    0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311
# 10   0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311
# 11   0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311
# ...

# %%
boston.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     1.716290   11.363636   11.136779    0.069170    0.554695    6.284634
# std      2.653510   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.250895    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      2.326718   12.500000   18.100000    0.000000    0.624000    6.623500
# max      9.966540  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# ## Task b) Simple Linear Regression

# %%
import scipy.stats as pstats
def lin_reg(x, y):
    r2 = 0
    xm = np.mean(x)
    ym = np.mean(y)
    #compute b_1
    fst = 0
    snd = 0
    for i,v in enumerate(x):
        fst += (x[i]-xm)*(y[i]-ym)
        snd += (x[i]-xm)**2
    b_1 = fst/snd
    #compute b_0
    b_0 = ym - b_1 * xm
    #compute y_r
    y_r = []
    for i,v in enumerate(x):
        y_r.append(b_0 + b_1 * x[i])
    #compute R² and SE of Slope
    fst = 0
    snd = 0
    thd = 0
    for i,v in enumerate(y):
        fst += (y[i] - y_r[i])**2
        #important to compute r
        snd += (y[i] - ym)**2
        #important to compute SE
        thd += (x[i] - xm)**2
    r2 = 1 - fst/snd
    SE = np.sqrt(fst/(len(y)-2)) / np.sqrt(thd)
    t = np.abs(b_1/SE)
    pval = pstats.t.sf(np.abs(b_1/SE), len(y)-2)
    #Pearson correlation and p value for non-correlation
    _, rpval = pstats.pearsonr(x,y)
    #quadric loss
    loss = 0
    for i,v in enumerate(y):
        loss += (y[i] - y_r[i])**2
    return b_1, b_0, np.sqrt(r2), t, pval, rpval, loss, y_r

# %%
#Compute all possible simple linear regression models
for i in columns[:-1]:
    b1, b0, r2, t, pval, rpval, loss, _ = lin_reg(list(boston[i]), list(boston['MEDV']))
    print("\n---",i,"---",
          "\nSlope:",b1, "\nIntercept:",b0, 
          "\nCoefficient of Determination:",r2,
          "\nt-statistic of slope:", t,
          "\np-Value:", pval, 
          "\npearson p-Value:", rpval, 
          "\nQuadric Loss:",loss)
# Out:
# --- CRIM ---
# Slope: -1.25496328506
# Intercept: 24.6866877071
# Coefficient of Determination: 0.362076763141
# t-statistic of slope: 8.72028982817
# p-Value: 2.02118544191e-17
# pearson p-Value: 4.04237088381e-17
# Quadric Loss: 37116.2069241
#
# --- ZN ---
# Slope: 0.142139994155
# Intercept: 20.9175791178
# Coefficient of Determination: 0.360445342451
# t-statistic of slope: 8.67511627005
# p-Value: 2.85679207654e-17
# pearson p-Value: 5.71358415308e-17
# Quadric Loss: 37166.5582239
#
# --- INDUS ---
# Slope: -0.648490053616
# Intercept: 29.7548965119
# Coefficient of Determination: 0.483725160028
# t-statistic of slope: 12.4078557026
# p-Value: 2.45012999088e-31
# pearson p-Value: 4.90025998175e-31
# Quadric Loss: 32721.1081504
#
# --- CHAS ---
# Slope: 6.34615711253
# Intercept: 22.0938428875
# Coefficient of Determination: 0.17526017719
# t-statistic of slope: 3.99643746609
# p-Value: 3.69531158526e-05
# pearson p-Value: 7.39062317052e-05
# Quadric Loss: 41404.2161444
#
# ...

# %% [markdown]
# According to R-Measure the linear model with features RM, PTRATIO, LSTAT explains most of the variation of data.
# According to p-Value the nearest models to significant fit are also RM, PTRATIO, LSTAT.
# Therefor we decide that those features fit best to combine for a multiple linear regression.

# %%
#plotting function for simple linear regression
def plotreg(x,y):
    _, _, _, _, _, _, _, y_r = lin_reg(x,y)
    plt.plot(x,y_r)
    plt.scatter(x,y)
    plt.show()
    plt.close()

# %%
plotreg(list(boston['RM']), list(boston['MEDV']))
plotreg(list(boston['PTRATIO']), list(boston['MEDV']))
plotreg(list(boston['LSTAT']), list(boston['MEDV']))

# %% [markdown]
# ## Task c) Multiple Linear Regression

# %%
def multi_lin_regr(X, Y):
    #Preprocess to convert for Matrix-Operations
    X = np.stack(X, axis=1)
    X = np.matrix(X)
    Y = np.matrix(Y).transpose()
    #compute coefficent-vector b
    b = np.linalg.inv(X.transpose()*X)*X.transpose()*Y
    #compute modeled Y
    Y_r = X*b
    #compute quadric loss
    #dist = (Y-Y_r)
    loss = 0
    dist = []
    for i,v in enumerate(Y.tolist()[0]):
        dist.append((Y.item(i)-Y_r.item(i))**2)
    for i,v in enumerate(dist):
        loss += dist[i]
    return b, loss

# %%
#Take the three significantly linear modelled features (according to p-value) and compute multiple regression models
Y = np.array(list(boston['MEDV']))
x1 = np.array(list(boston['RM']))
x2 = np.array(list(boston['PTRATIO']))
x3 = np.array(list(boston['LSTAT']))
X = np.stack((x1,x2))
print("linear regression with features RM, PTRATIO\n", multi_lin_regr(X, Y))
X = np.stack((x1,x3))
print("linear regression with features RM, LSTAT\n", multi_lin_regr(X, Y))
X = np.stack((x2,x3))
print("linear regression with features PTRATIO, LSTAT\n", multi_lin_regr(X, Y))
# Out:
# linear regression with features RM, PTRATIO
#  (matrix([[ 7.50396716],
#         [-1.33380785]]), 24.317956016196888)
# linear regression with features RM, LSTAT
#  (matrix([[ 4.90690607],
#         [-0.65573999]]), 24.97322973456098)
# linear regression with features PTRATIO, LSTAT
#  (matrix([[ 1.85724124],
#         [-0.98421119]]), 0.2357887053964264)

# %% [markdown]
# The combination of the features with smallest p-values has the smallest loss.
